# %% [markdown]
# Markdowns are for descriptions/anything that's not code

# %% [markdown]
# There are different ways of changing fonts, easiest way is:
# # big text
# ## slightly smaller
# ### smallest

# %%
print("Hello World")
# Out:
# Hello World
